# %% [markdown]
# ### GSV-Cities dataset download script
#
# In this notebook, we will download GSV-Cities dataset **without** Kaggle API key or login.
# The official kaggle page for GSV-Cities is: https://www.kaggle.com/datasets/amaralibey/gsv-cities
# If you have a Kaggle account, please give it an **Upvote**.
#
# **NOTE**: the dataset size is 23GB, make sure you have enough space on your disk.
# You also have the option to download the dataset from command line when running the training for the first time.
#
#
#
# ___

# %% [markdown]
# ##### Bibtex code for citation:
# <small>
#
# ```bibtex
# @article{ali2022gsv,
#     title={{GSV-Cities}: Toward appropriate supervised visual place recognition},
#     author={Ali-bey, Amar and Chaib-draa, Brahim and Gigu{\`e}re, Philippe},
#     journal={Neurocomputing},
#     volume={513},
#     pages={194--203},
#     year={2022},
#     publisher={Elsevier}
# }
# ```
# ___

# %%
# First, choose where to save the gsv-cities dataset
save_path = "../data/train/gsv-cities"

# %%
# We can actually download public datasets directly from kaggle 
# without authentification using the kaggle CLI
# but first, make sure you have it installed
! pip install kaggle -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: kaggle in /home/wt/.local/lib/python3.13/site-packages (1.8.3)
# Requirement already satisfied: black>=24.10.0 in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (26.1.0)
# Requirement already satisfied: bleach in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (0.1.15)
# Requirement already satisfied: mypy>=1.15.0 in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (2.32.4.20260107)
# Requirement already satisfied: types-tqdm in /home/wt/.local/lib/python3.13/site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.6.1)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (8.2.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/wt/.local/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /home/wt/.local/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (4.5.0)
# Requirement already satisfied: pytokens>=0.3.0 in /home/wt/.local/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (0.4.1)
# Requirement already satisfied: typing_extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in /home/wt/.local/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (0.7.8)
# Requirement already satisfied: webencodings in /home/wt/.local/lib/python3.13/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/wt/.local/lib/python3.13/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (2025.11.12)

# %%
# start the download, and unzip the dataset
! kaggle datasets download "amaralibey/gsv-cities" -p {save_path} --unzip
# Out:
# /bin/bash: kaggle：未找到命令

# %% [markdown]
# #### Hard code the path to GSV-Cities into `config.yaml`

# %%
import yaml
from pathlib import Path

# Now that the download is complete, we will write the path to the config file

with open("../config/data/config.yaml", "r") as f:
    config = yaml.safe_load(f)


# we need the absolute path to the dataset
save_path = Path(save_path).resolve().as_posix()

config["train"]["gsv_cities"] = save_path

with open('../config/data/config.yaml', 'w') as f:
    yaml.dump(config, f)

# %%
print(config["gsv_cities_path"])
# Out:
# /home/amar/work/DeepVPRLab/data/train/gsv-cities

# %% [markdown]
# ### ALL DONE!
